# %%
import numpy as np#importing the numpy library
import tensorflow as tf#importing the tensorflowlibrary
import pandas as pd#importing the pandas library
import seaborn as sns #importing the seaborn library
from sklearn.preprocessing import MinMaxScaler#importing the min max scalar library
import matplotlib.pyplot as plt#importing the matplot lib library

# %%
df = pd.read_csv('time_series_data.csv',index_col='Month')#loading the dataset
df.index = pd.to_datetime(df.index)#using datetime to read dates from dataset
df.head(2) #printing the dataset

# %%
scalar = MinMaxScaler()#defining a min max scalar

# %%
train_size = int(len(df) * 0.8)
train_data, test_data = df[:train_size], df[train_size:]

# %%
train_data.head(11)
# Out:
#                      Milk Production
# Month
# 1962-01-01 01:00:00            589.0
# 1962-02-01 01:00:00            561.0
# 1962-03-01 01:00:00            640.0
# 1962-04-01 01:00:00            656.0
# 1962-05-01 01:00:00            727.0
# 1962-06-01 01:00:00            697.0
# 1962-07-01 01:00:00            640.0
# 1962-08-01 01:00:00            599.0
# 1962-09-01 01:00:00            568.0
# 1962-10-01 01:00:00            577.0
# 1962-11-01 01:00:00            553.0

# %%
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data.iloc[i:i + sequence_length].values)
        y.append(data.iloc[i + sequence_length].values)
    return np.array(X), np.array(y)

# %%
# Assuming train_data and test_data are already defined DataFrames with 'Milk Production' and other relevant columns

# Define sequence length
sequence_length = 10

# Generate sequences for training data
X_train, y_train = create_sequences(train_data, sequence_length)

# Generate sequences for testing data
X_test, y_test = create_sequences(test_data, sequence_length)

# Display the shapes to ensure they are correctly formed
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (124, 10, 1)
# y_train shape: (124, 1)
# X_test shape: (24, 10, 1)
# y_test shape: (24, 1)

# %%
X_train[0][0] , y_train
# Out:
# (array([589.]),
#  array([[553.],
#         [582.],
#         [600.],
#         [566.],
#         [653.],
#         [673.],
#         [742.],
#         [716.],
#         [660.],
#         [617.],
#         [583.],
#         [587.],
#         [565.],
#         [598.],
#         [628.],
#         [618.],
#         [688.],
#         [705.],
#         [770.],
#         [736.],
#         [678.],
#         [639.],
#         [604.],
#         [611.],
#         [594.],
#         [634.],
#         [658.],
#         [622.],
#         [709.],
#         [722.],
#         [782.],
#         [756.],
#         [702.],
#         [653.],
#         [615.],
#         [621.],
#         [602.],
#         [635.],
#         [677.],
#         [635.],
#         [736.],
#         [755.],
#         [811.],
#         [798.],
#         [735.],
#         [697.],
#         [661.],
#         [667.],
#         [645.],
#         [688.],
#         [713.],
#         [667.],
#         [762.],
#         [784.],
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Flatten , Embedding , TextVectorization , GlobalAveragePooling1D , LSTM

# %%
# Define the LSTM model
model = Sequential()

# Add an LSTM layer
model.add(LSTM(units=50, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])))

# Add a Dense layer with a linear activation function (default)
model.add(Dense(1))

# Compile the model
model.compile(optimizer='Adam', loss='mean_squared_error' , metrics=['accuracy'])

# Print the model summary
model.summary()

# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 324ms/step - accuracy: 0.0000e+00 - loss: 550361.6875 - val_accuracy: 0.0000e+00 - val_loss: 742294.2500
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.0000e+00 - loss: 545632.1250 - val_accuracy: 0.0000e+00 - val_loss: 742045.0000
# Epoch 3/200
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error , root_mean_squared_error

# Predict on test data
y_pred = model.predict(X_test)

# Calculate regression metrics
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f'Test rMSE: {rmse}')
print(f'Test MAE: {mae}')
print(f'Test MAPE: {mape}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Test rMSE: 847.3049779896824
# Test MAE: 845.2974688212076
# Test MAPE: 0.982205003995798
